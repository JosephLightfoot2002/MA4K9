# %%
import numpy as np
import math
import torch
from mpl_toolkits.mplot3d import Axes3D
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import math
# ----> 3 import torch
#       4 from mpl_toolkits.mplot3d import Axes3D
#       5 import torch.nn as nn
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:2475
#    2471     torch_module_name = ".".join([__name__, device_type])
#    2472     sys.modules[torch_module_name] = module
# -> 2475 from torch import (
#    2476     export as export,
#    2477     func as func,
#    2478     library as library,
#    2479     return_types as return_types,
#    2480 )
#    2481 from torch._higher_order_ops import cond as cond, while_loop as while_loop
#    2482 from torch.func import vmap as vmap
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\__init__.py:64
#      41     from torch.fx.experimental.symbolic_shapes import StrictMinMaxConstraint
#      44 __all__ = [
#      45     "Constraint",
#      46     "Dim",
#    (...)
#      60     "UnflattenedModule",
#      61 ]
# ---> 64 from .dynamic_shapes import Constraint, Dim, dims, ShapesCollection
#      65 from .exported_program import ExportedProgram, ModuleCallEntry, ModuleCallSignature
#      66 from .graph_signature import ExportBackwardSignature, ExportGraphSignature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\dynamic_shapes.py:23
#      10 import torch
#      11 from torch.utils._pytree import (
#      12     _get_node_type,
#      13     BUILTIN_TYPES,
#    (...)
#      20     tree_map_with_path,
#      21 )
# ---> 23 from .exported_program import ExportedProgram
#      26 if TYPE_CHECKING:
#      27     from sympy import Symbol
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\exported_program.py:26
#      11 from contextlib import contextmanager
#      12 from typing import (
#      13     Any,
#      14     Callable,
#    (...)
#      23     Union,
#      24 )
# ---> 26 from torch._higher_order_ops.utils import autograd_not_implemented
#      27 from torch._library.fake_class_registry import FakeScriptObject
#      28 from torch.fx._utils import first_call_function_nn_module_stack
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_higher_order_ops\__init__.py:1
# ----> 1 from torch._higher_order_ops.cond import cond
#       2 from torch._higher_order_ops.flex_attention import (
#       3     flex_attention,
#       4     flex_attention_backward,
#       5 )
#       6 from torch._higher_order_ops.hints_wrap import hints_wrapper
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_higher_order_ops\cond.py:6
#       3 import logging
#       5 import torch
# ----> 6 import torch._subclasses.functional_tensor
#       7 import torch.utils._pytree as pytree
#       8 from torch._C import DispatchKey
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_subclasses\functional_tensor.py:9
#       6 from typing import Any, Callable, ContextManager, Dict, List, Optional, Tuple, Union
#       8 import torch
# ----> 9 import torch._inductor.config as inductor_config
#      10 import torch.utils._pytree as pytree
#      11 from torch._C import _functionalization_reapply_views_tls as _reapply_views
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_inductor\config.py:44
#      40 verbose_progress = False
#      42 # use fx aot graph codegen cache
#      43 fx_graph_cache = (
# ---> 44     os.environ.get("TORCHINDUCTOR_FX_GRAPH_CACHE", "0" if is_fbcode() else "1") == "1"
#      45 )
#      47 # use remote fx aot graph codegen cache
#      48 # False: Disables the cache
#      49 # True: Enables the cache
#      50 # None: Not set -- Off for OSS, JustKnobs based for internal
#      51 fx_graph_remote_cache: Optional[bool] = fx_graph_remote_cache_default()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_inductor\config.py:9, in is_fbcode()
#       8 def is_fbcode() -> bool:
# ----> 9     return not hasattr(torch.version, "git_version")
#
# AttributeError: partially initialized module 'torch' has no attribute 'version' (most likely due to a circular import)

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\__init__.py:2475
#    2471     torch_module_name = ".".join([__name__, device_type])
#    2472     sys.modules[torch_module_name] = module
# -> 2475 from torch import (
#    2476     export as export,
#    2477     func as func,
#    2478     library as library,
#    2479     return_types as return_types,
#    2480 )
#    2481 from torch._higher_order_ops import cond as cond, while_loop as while_loop
#    2482 from torch.func import vmap as vmap
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\__init__.py:64
#      41     from torch.fx.experimental.symbolic_shapes import StrictMinMaxConstraint
#      44 __all__ = [
#      45     "Constraint",
#      46     "Dim",
#    (...)
#      60     "UnflattenedModule",
#      61 ]
# ---> 64 from .dynamic_shapes import Constraint, Dim, dims, ShapesCollection
#      65 from .exported_program import ExportedProgram, ModuleCallEntry, ModuleCallSignature
#      66 from .graph_signature import ExportBackwardSignature, ExportGraphSignature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\dynamic_shapes.py:23
#      10 import torch
#      11 from torch.utils._pytree import (
#      12     _get_node_type,
#      13     BUILTIN_TYPES,
#    (...)
#      20     tree_map_with_path,
#      21 )
# ---> 23 from .exported_program import ExportedProgram
#      26 if TYPE_CHECKING:
#      27     from sympy import Symbol
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\export\exported_program.py:26
#      11 from contextlib import contextmanager
#      12 from typing import (
#      13     Any,
#      14     Callable,
#    (...)
#      23     Union,
#      24 )
# ---> 26 from torch._higher_order_ops.utils import autograd_not_implemented
#      27 from torch._library.fake_class_registry import FakeScriptObject
#      28 from torch.fx._utils import first_call_function_nn_module_stack
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_higher_order_ops\__init__.py:1
# ----> 1 from torch._higher_order_ops.cond import cond
#       2 from torch._higher_order_ops.flex_attention import (
#       3     flex_attention,
#       4     flex_attention_backward,
#       5 )
#       6 from torch._higher_order_ops.hints_wrap import hints_wrapper
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_higher_order_ops\cond.py:6
#       3 import logging
#       5 import torch
# ----> 6 import torch._subclasses.functional_tensor
#       7 import torch.utils._pytree as pytree
#       8 from torch._C import DispatchKey
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_subclasses\functional_tensor.py:9
#       6 from typing import Any, Callable, ContextManager, Dict, List, Optional, Tuple, Union
#       8 import torch
# ----> 9 import torch._inductor.config as inductor_config
#      10 import torch.utils._pytree as pytree
#      11 from torch._C import _functionalization_reapply_views_tls as _reapply_views
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_inductor\config.py:44
#      40 verbose_progress = False
#      42 # use fx aot graph codegen cache
#      43 fx_graph_cache = (
# ---> 44     os.environ.get("TORCHINDUCTOR_FX_GRAPH_CACHE", "0" if is_fbcode() else "1") == "1"
#      45 )
#      47 # use remote fx aot graph codegen cache
#      48 # False: Disables the cache
#      49 # True: Enables the cache
#      50 # None: Not set -- Off for OSS, JustKnobs based for internal
#      51 fx_graph_remote_cache: Optional[bool] = fx_graph_remote_cache_default()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_inductor\config.py:9, in is_fbcode()
#       8 def is_fbcode() -> bool:
# ----> 9     return not hasattr(torch.version, "git_version")
#
# AttributeError: partially initialized module 'torch' has no attribute 'version' (most likely due to a circular import)

# %%
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 torch.cuda.is_available()
#
# NameError: name 'torch' is not defined

# %%
class GenericNetwork(nn.Module):

    def __init__(self, layers,activation):

        super(GenericNetwork, self).__init__()
        self.layers = nn.ModuleList()

        for i in range(len(layers) - 1):
            self.layers.append(nn.Linear(layers[i], layers[i + 1]))

        self.activation = activation

    def forward(self, x):

        for i in range(len(self.layers) - 1):
            x = self.activation(self.layers[i](x))

        x = self.layers[-1](x)
        
        return x

# %%
model = GenericNetwork([2,10,1],nn.ReLU()).to(device)

# %%
criterion = nn.MSELoss() 
optimizer = optim.Adam(model.parameters(), lr=0.05)

# %%
device=torch.device("cuda")

# %%
def generatePoints(num_samples):  
    x1 = torch.linspace(-5, 5, num_samples)  
    x2 = torch.linspace(-5, 5, num_samples)  
    X1, X2 = torch.meshgrid(x1, x2)  
    Y = torch.sin(X1)*torch.cos(X2)

    
    x = torch.cat([X1.contiguous().view(-1,1), X2.contiguous().view(-1,1)], dim=1) 
    y = Y.view(-1, 1)  
    return x.to(device),y.to(device)

# %%
epochs = 100000

for epoch in range(epochs):
    model.train()
    y_pred = model(x)
    
    loss = criterion(y_pred, y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f'Epoch {epoch+1}/{epochs}, Loss: {loss.item()}')
# Out:
# Epoch 100/100000, Loss: 0.18981336057186127
# Epoch 200/100000, Loss: 0.09383189678192139
# Epoch 300/100000, Loss: 0.06375699490308762
# Epoch 400/100000, Loss: 0.058489006012678146
# Epoch 500/100000, Loss: 0.04098028317093849
# Epoch 600/100000, Loss: 0.023649968206882477
# Epoch 700/100000, Loss: 0.023354243487119675
# Epoch 800/100000, Loss: 0.028603026643395424
# Epoch 900/100000, Loss: 0.023214804008603096
# Epoch 1000/100000, Loss: 0.023196334019303322
# Epoch 1100/100000, Loss: 0.02535727061331272
# Epoch 1200/100000, Loss: 0.023600416257977486
# Epoch 1300/100000, Loss: 0.028013641014695168
# Epoch 1400/100000, Loss: 0.023085536435246468
# Epoch 1500/100000, Loss: 0.023137127980589867
# Epoch 1600/100000, Loss: 0.023033298552036285
# Epoch 1700/100000, Loss: 0.023020928725600243
# Epoch 1800/100000, Loss: 0.026213781908154488
# Epoch 1900/100000, Loss: 0.025308843702077866
# Epoch 2000/100000, Loss: 0.0229499414563179
# Epoch 2100/100000, Loss: 0.023159349337220192
# Epoch 2200/100000, Loss: 0.022923968732357025
# Epoch 2300/100000, Loss: 0.022934677079319954
# Epoch 2400/100000, Loss: 0.023002879694104195
# Epoch 2500/100000, Loss: 0.022915152832865715
# Epoch 2600/100000, Loss: 0.022903231903910637
# Epoch 2700/100000, Loss: 0.02293298952281475
# Epoch 2800/100000, Loss: 0.02309153974056244
# Epoch 2900/100000, Loss: 0.039295509457588196
# Epoch 3000/100000, Loss: 0.02289777807891369
# Epoch 3100/100000, Loss: 0.023288728669285774
# Epoch 3200/100000, Loss: 0.022896770387887955
# Epoch 3300/100000, Loss: 0.022913677617907524
# Epoch 3400/100000, Loss: 0.022905733436346054
# Epoch 3500/100000, Loss: 0.02290211245417595
# Epoch 3600/100000, Loss: 0.02290421910583973
# Epoch 3700/100000, Loss: 0.024810288101434708
# Epoch 3800/100000, Loss: 0.023101424798369408
# Epoch 3900/100000, Loss: 0.029370861127972603
# Epoch 4000/100000, Loss: 0.022899825125932693
# Epoch 4100/100000, Loss: 0.022904135286808014
# Epoch 4200/100000, Loss: 0.022901887074112892
# Epoch 4300/100000, Loss: 0.022897599264979362
# Epoch 4400/100000, Loss: 0.030028562992811203
# Epoch 4500/100000, Loss: 0.022893331944942474
# Epoch 4600/100000, Loss: 0.023329224437475204
# Epoch 4700/100000, Loss: 0.023187315091490746
# Epoch 4800/100000, Loss: 0.026422778144478798
# Epoch 4900/100000, Loss: 0.022893358021974564
# Epoch 5000/100000, Loss: 0.022922759875655174
# Epoch 5100/100000, Loss: 0.023597754538059235
# Epoch 5200/100000, Loss: 0.022900741547346115
# Epoch 5300/100000, Loss: 0.04847010597586632
# Epoch 5400/100000, Loss: 0.022894928231835365
# Epoch 5500/100000, Loss: 0.026007255539298058
# Epoch 5600/100000, Loss: 0.0228931475430727
# Epoch 5700/100000, Loss: 0.024425087496638298
# Epoch 5800/100000, Loss: 0.022908858954906464
# Epoch 5900/100000, Loss: 0.02290327101945877
# Epoch 6000/100000, Loss: 0.02312552183866501
# Epoch 6100/100000, Loss: 0.022892514243721962
# Epoch 6200/100000, Loss: 0.022916870191693306
# Epoch 6300/100000, Loss: 0.02367832139134407
# Epoch 6400/100000, Loss: 0.022922642529010773
# Epoch 6500/100000, Loss: 0.023057974874973297
# Epoch 6600/100000, Loss: 0.03488651663064957
# Epoch 6700/100000, Loss: 0.02289184182882309
# Epoch 6800/100000, Loss: 0.025114376097917557
# Epoch 6900/100000, Loss: 0.022897161543369293
# Epoch 7000/100000, Loss: 0.02293490804731846
# Epoch 7100/100000, Loss: 0.025480471551418304
# Epoch 7200/100000, Loss: 0.02289409004151821
# Epoch 7300/100000, Loss: 0.038847777992486954
# Epoch 7400/100000, Loss: 0.02292872779071331
# Epoch 7500/100000, Loss: 0.02290717512369156
# Epoch 7600/100000, Loss: 0.023896217346191406
# Epoch 7700/100000, Loss: 0.022892115637660027
# Epoch 7800/100000, Loss: 0.025169750675559044
# Epoch 7900/100000, Loss: 0.02300303615629673
# Epoch 8000/100000, Loss: 0.02426931820809841
# Epoch 8100/100000, Loss: 0.022897662594914436
# Epoch 8200/100000, Loss: 0.022899435833096504
# Epoch 8300/100000, Loss: 0.02327018603682518
# Epoch 8400/100000, Loss: 0.02917591482400894
# Epoch 8500/100000, Loss: 0.023047253489494324
# Epoch 8600/100000, Loss: 0.02297511138021946
# Epoch 8700/100000, Loss: 0.022895805537700653
# Epoch 8800/100000, Loss: 0.025682255625724792
# Epoch 8900/100000, Loss: 0.022894395515322685
# Epoch 9000/100000, Loss: 0.060170046985149384
# Epoch 9100/100000, Loss: 0.02289324440062046
# Epoch 9200/100000, Loss: 0.0230683833360672
# Epoch 9300/100000, Loss: 0.02312564291059971
# Epoch 9400/100000, Loss: 0.023178216069936752
# Epoch 9500/100000, Loss: 0.022894419729709625
# Epoch 9600/100000, Loss: 0.02452206425368786
# Epoch 9700/100000, Loss: 0.022891825065016747
# Epoch 9800/100000, Loss: 0.022939587011933327
# Epoch 9900/100000, Loss: 0.02289404161274433
# Epoch 10000/100000, Loss: 0.034482479095458984
# Epoch 10100/100000, Loss: 0.03870503604412079
# Epoch 10200/100000, Loss: 0.03372475504875183
# Epoch 10300/100000, Loss: 0.023368358612060547
# Epoch 10400/100000, Loss: 0.02289300411939621
# Epoch 10500/100000, Loss: 0.023786669597029686
# Epoch 10600/100000, Loss: 0.053769297897815704
# Epoch 10700/100000, Loss: 0.022892532870173454
# Epoch 10800/100000, Loss: 0.023660030215978622
# Epoch 10900/100000, Loss: 0.022895578294992447
# Epoch 11000/100000, Loss: 0.022898299619555473
# Epoch 11100/100000, Loss: 0.022913651540875435
# Epoch 11200/100000, Loss: 0.022890986874699593
# Epoch 11300/100000, Loss: 0.022988997399806976
# Epoch 11400/100000, Loss: 0.022891193628311157
# Epoch 11500/100000, Loss: 0.02380019798874855
# Epoch 11600/100000, Loss: 0.023019228130578995
# Epoch 11700/100000, Loss: 0.0486474335193634
# Epoch 11800/100000, Loss: 0.02289443276822567
# Epoch 11900/100000, Loss: 0.05991348624229431
# Epoch 12000/100000, Loss: 0.022893544286489487
# Epoch 12100/100000, Loss: 0.024354051798582077
# Epoch 12200/100000, Loss: 0.023333685472607613
# Epoch 12300/100000, Loss: 0.02291971817612648
# Epoch 12400/100000, Loss: 0.023187533020973206
# Epoch 12500/100000, Loss: 0.02289138175547123
# Epoch 12600/100000, Loss: 0.023457419127225876
# Epoch 12700/100000, Loss: 0.022899767383933067
# Epoch 12800/100000, Loss: 0.0229243915528059
# Epoch 12900/100000, Loss: 0.022897854447364807
# Epoch 13000/100000, Loss: 0.024415338411927223
# Epoch 13100/100000, Loss: 0.027538884431123734
# Epoch 13200/100000, Loss: 0.02292620576918125
# Epoch 13300/100000, Loss: 0.06391184777021408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       7 loss = criterion(y_pred, y)
#       9 optimizer.zero_grad()
# ---> 10 loss.backward()
#      11 optimizer.step()
#      13 if (epoch+1) % 100 == 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\autograd\__init__.py:340, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     331 inputs = (
#     332     (inputs,)
#     333     if isinstance(inputs, (torch.Tensor, graph.GradientEdge))
#    (...)
#     336     else ()
#     337 )
#     339 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 340 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     341 if retain_graph is None:
#     342     retain_graph = create_graph
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\autograd\__init__.py:220, in _make_grads(outputs, grads, is_grads_batched)
#     217     else:
#     218         assert isinstance(out, torch.Tensor)
#     219         new_grads.append(
# --> 220             torch.ones_like(out, memory_format=torch.preserve_format)
#     221         )
#     222 else:
#     223     new_grads.append(None)
#
# KeyboardInterrupt:

# %%
x1 = torch.linspace(-3, 3, 50)  # 100 points in x
x2 = torch.linspace(-3, 3, 50)  # 100 points in y
X1, X2 = torch.meshgrid(x1, x2)  # Create a grid of points
Y = torch.exp(-(X1**2 + X2**2))  # Gaussian function: e^(-(x^2 + y^2))

# Reshape the input data for the neural network
x = torch.cat([X1.contiguous().view(-1,1), X2.contiguous().view(-1,1)], dim=1)  # Shape: (10000, 2)
y = Y.view(-1, 1)  # Shape: (10000, 1)
# Out:
# C:\Users\jmlig\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce GTX 1060 6GB

# %%
x,y=generatePoints(100)
# Out:
# C:\Users\jmlig\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
xnp=x.to("cpu")
ynp=y.to("cpu")
xnp=np.array(xnp.T[0])
ynp=np.array(xnp.T[1])
znp=np.array(ynp.T)

ax.plot3D(xnp,ynp,znp, 'green')


ax.set_title('3D line Gaussian')
plt.show()
fig = plt.figure()
 
# syntax for 3-D projection
ax2= plt.axes(projection ='3d')
xnp=np.array(xnp.T[0])
ynp=np.array(xnp.T[1])
ax2.plot3D(xnp,ynp,model(x).detach().T[0],"red",alpha=0.2)


ax.set_title('3D line NN')
plt.show()
# Out:
# C:\Users\jmlig\AppData\Local\Temp\ipykernel_13944\3992609516.py:7: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   xnp=np.array(xnp.T[0])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 21
#      19 ax2= plt.axes(projection ='3d')
#      20 xnp=np.array(xnp.T[0])
# ---> 21 ynp=np.array(xnp.T[1])
#      22 ax2.plot3D(xnp,ynp,model(x).detach().T[0],"red",alpha=0.2)
#      25 ax.set_title('3D line NN')
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
